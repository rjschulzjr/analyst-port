# %% [markdown]
# # Module 6. Data Manipulation and Analysis with Pandas.
#
# **_Author: Favio Vázquez_**
#
# **_Reviewer: Jessica Cervi_**
#
# **Expected time = 3 hours**
#
# **Total points = 105 points**

# %% [markdown]
# ## Assignment Overview
#
# In this assignment you will manipulate and analyze data with Pandas. You will begin by reviewing how to read data into a series or dataframe, then you will use additional functionalities of Pandas objects. After that, you will index, select and edit data inside dataframes. In the final parts of the assignment you will be combining, grouping and aggregating dataframes.
#
# This assignment is designed to build your familiarity and comfort coding in Python while also helping you review key topics from each module. As you progress through the assignment, answers will get increasingly complex. It is important that you adopt a data scientist's mindset when completing this assignment. **Remember to run your code from each cell before submitting your assignment.** Running your code beforehand will notify you of errors and give you a chance to fix your errors before submitting. You should view your Vocareum submission as if you are delivering a final project to your manager or client.
#
# ***Vocareum Tips***
# - Do not add arguments or options to functions unless you are specifically asked to. This will cause an error in Vocareum.
# - Do not use a library unless you are explicitly asked to in the question.
# - You can download the Grading Report after submitting the assignment. This will include feedback and hints on incorrect questions.
#
#
# ### Learning Objectives
#
# - Use Pandas to build, extract, filter, and transform DataFrames.
# - Describe Pandas data structures: DataFrames and Series.
# - Use Pandas objects for analyses.

# %% [markdown]
# ## Index:
#
# #### Module 6: Data Manipulation and Analysis with Pandas.
#
# - [Question 1](#Question-1)
# - [Question 2](#Question-2)
# - [Question 3](#Question-3)
# - [Question 4](#Question-4)
# - [Question 5](#Question-5)
# - [Question 6](#Question-6)
# - [Question 7](#Question-7)
# - [Question 8](#Question-8)
# - [Question 9](#Question-9)
# - [Question 10](#Question-10)
# - [Question 11](#Question-11)
# - [Question 12](#Question-12)
# - [Question 13](#Question-13)
# - [Question 14](#Question-14)

# %%
# Let's start by importing Pandas
import pandas as pd

# Avoid warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Importing data
#
# We will begin this assignment with a review of how to import data with Pandas. For several parts of this assignment we will be using two datasets coming from the past 120 years of Olympic history: athletes and results. This dataset is saved inside the folder `/data`; more information about this dataset can be found on Kaggle at this link:
#
# https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results
#
# This is a historical dataset on the modern Olympic Games, including all the Games from Athens 1896 to Rio 2016.
#
# The file `athlete_events.csv` contains 271116 rows and 15 columns. Each row corresponds to an individual athlete competing in an individual Olympic event (athlete-events). The columns are:
#
# - ID - Unique number for each athlete
# - Name - Athlete's name
# - Sex - M or F
# - Age - Athlete's age
# - Height - In centimeters
# - Weight - In kilograms
# - Team - Team name
# - NOC - National Olympic Committee 3-letter code
# - Games - Year and season
# - Year - Year of game
# - Season - Summer or Winter
# - City - Host city
# - Sport - Sport
# - Event - Event
# - Medal - Gold, Silver, Bronze, or NA
#
# The file `noc_regions.csv` contains 230 rows and 3 columns. Each row contains information about the different National Olympic Committee (NOC). The columns are:
#
# - NOC - National Olympic Committee abreviation
# - region - Name of country in NOC
# - notes - Notes about the region and NOC
#
#
# [Back to top](#Index:)

# %% [markdown]
# ### Question 1
# *5 points*
#
# Read the CSV file named `"athlete_events.csv"` contained in the `data/` folder and assign it to a dataframe called `df`.

# %%
### GRADED

### YOUR SOLUTION HERE
df = pd.read_csv('data/athlete_events.csv')
df
###
### YOUR CODE HERE
###
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-6ffd39de9e47> in <module>
#       2
#       3 ### YOUR SOLUTION HERE
# ----> 4 df = pd.read_csv('data/athlete_events.csv')
#       5 df
#       6 ###
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File data/athlete_events.csv does not exist: 'data/athlete_events.csv'

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %%
# Let's take a look at our dataframe df
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-270e621faa49> in <module>
#       1 # Let's take a look at our dataframe df
# ----> 2 df.head()
#
# NameError: name 'df' is not defined

# %%
# Let's see the shape of out dataframe df
print("Number of rows: {}, number of columns: {}".format(df.shape[0],df.shape[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-373aaf3b8c0b> in <module>
#       1 # Let's see the shape of out dataframe df
# ----> 2 print("Number of rows: {}, number of columns: {}".format(df.shape[0],df.shape[1]))
#
# NameError: name 'df' is not defined

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 2
# *5 points*
#
# Read the CSV file named `"noc_regions.csv"` in the `data/` folder and assign it to a dataframe called `regions`.

# %%
### GRADED

### YOUR SOLUTION HERE
regions = pd.read_csv('data/noc_regions.csv')
regions

###
### YOUR CODE HERE
###
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-6983f7a8021e> in <module>
#       2
#       3 ### YOUR SOLUTION HERE
# ----> 4 regions = pd.read_csv('data/noc_regions.csv')
#       5 regions
#       6
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File data/noc_regions.csv does not exist: 'data/noc_regions.csv'

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %%
# count of values
regions['region'].value_count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ff896f4f582c> in <module>
#       1 # count of values
# ----> 2 region['regions'].value_count()
#
# NameError: name 'region' is not defined

# %%
# outputs each column and the sum of nulls in that column
df.isnull().sum()

# %%
# Let's take a look at our dataframe regions
regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
# Let's see the shape of out dataframe regions
print("Number of rows: {}, number of columns: {}".format(regions.shape[0],regions.shape[1]))
# Out:
# Number of rows: 230, number of columns: 3

# %% [markdown]
# ### Pandas Objects
#
# In this part of the assignment we will begin studying the two most important objects exposed by Pandas: Series and Dataframes. As you remember:
# - **Series** is a 1 dimensional data structure in Pandas.
# - **DataFrame** is a 2 dimentional data structure in Pandas, made up of columns and rows.

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 3
# *5 points*
#
# Select a series from the dataframe `df` with the contents of the column `Height` and store it in a variable called `height`.

# %%
### GRADED

### YOUR SOLUTION HERE
height = df["Height"]
height
###
### YOUR CODE HERE
###
# Out:
# 0         180.0
# 1         170.0
# 2           NaN
# 3           NaN
# 4         185.0
# 5         185.0
# 6         185.0
# 7         185.0
# 8         185.0
# 9         185.0
# 10        188.0
# 11        188.0
# 12        188.0
# 13        188.0
# 14        188.0
# 15        188.0
# 16        188.0
# 17        188.0
# 18        183.0
# 19        183.0
# 20        183.0
# 21        183.0
# 22        183.0
# 23        183.0
# 24        183.0
# 25        183.0
# 26        168.0
# 27        168.0
# 28        186.0
# 29          NaN
#           ...
# 271086    177.0
# 271087    189.0
# 271088    189.0
# 271089    192.0
# 271090    192.0
# 271091    200.0
# 271092    182.0
# 271093    182.0
# 271094    182.0
# 271095    182.0
# 271096    182.0
# 271097    182.0
# 271098    182.0
# 271099    171.0
# 271100      NaN
# 271101    173.0
# 271102    171.0
# 271103    171.0
# 271104    172.0
# 271105    168.0
# 271106    168.0
# 271107    175.0
# 271108    183.0
# 271109    183.0
# 271110    171.0
# 271111    179.0
# 271112    176.0
# 271113    176.0
# 271114    185.0
# 271115    185.0
# Name: Height, Length: 271116, dtype: float64

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 4
# *10 points*
#
# In the videos, you have seen how you can use the function `map` to transform the entries of a `pandas` `series`.
# In a similar way, you can use the function `rename` to replace the entries of a series. Like `map`, `rename` takes as argument a lambda function executing the desired transformation on the `series`.
#
# The syntax is as follows
# ```Python
# new_series = series.rename(lambda x: your function)
# ```
#
# Use the function `rename` to rename the index (or labels) of the series `height` by raising each old label to the power of two, like so:
#
# $$
# 0 \rightarrow 0 \\
# 1 \rightarrow 1 \\
# 2 \rightarrow 4 \\
# 3 \rightarrow 9 \\
# \vdots
# $$
#
# Save this new series in a variable called `height_new`.

# %%
### GRADED

### YOUR SOLUTION HERE
height_new = height.rename(lambda x:x**2)

height_new.head()

###
### YOUR CODE HERE
###
# Out:
# 0     180.0
# 1     170.0
# 4       NaN
# 9       NaN
# 16    185.0
# Name: Height, dtype: float64

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 5
# *5 points*
#
# Select a series from the dataframe `regions` with the contents of the column `region` and store it in a variable called `reg`.

# %%
### GRADED

### YOUR SOLUTION HERE
reg = regions["region"]
reg.head()


###
### YOUR CODE HERE
###
# Out:
# 0    Afghanistan
# 1        Curacao
# 2        Albania
# 3        Algeria
# 4        Andorra
# Name: region, dtype: object

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 6
# *5 points*
#
# You can also select multiple columns at once from a dataframe to create a new dataframe.
#
#
# Create a new dataframe from the dataframe `df`, that only contain the columns `ID`, `Age`, `Height`, `Weight` and `Sex` in this specific order. Name this new dataframe `df_subset`.

# %%
### GRADED

### YOUR SOLUTION HERE
df_subset = df[["ID", "Age", "Height", "Weight", "Sex"]]
df_subset.head()

###
### YOUR CODE HERE
###
# Out:
#    ID   Age  Height  Weight Sex
# 0   1  24.0   180.0    80.0   M
# 1   2  23.0   170.0    60.0   M
# 2   3  24.0     NaN     NaN   M
# 3   4  34.0     NaN     NaN   M
# 4   5  21.0   185.0    82.0   F

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# Let's have a look at the dataframe `df_subset` by using the command `.head()`

# %%
df_subset.head()
# Out:
#    ID   Age  Height  Weight Sex
# 0   1  24.0   180.0    80.0   M
# 1   2  23.0   170.0    60.0   M
# 2   3  24.0     NaN     NaN   M
# 3   4  34.0     NaN     NaN   M
# 4   5  21.0   185.0    82.0   F

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 7
# *10 points*
#
# Observe the dataframe `df_subset`, above. You see that the column `Sex` contains entries `M` and `F` based on whether an athlete was a male or a female, respectively.
#
# Create a new column, `New sex`, in our dataframe. Fill this column by using the function `map` to change the entries of the column `sex` from `M` to `male` and from `F` to `female`.
#
# The syntax is as follows
# ```Python
# dataframe['column'] = dataframe.column.map(lambda x: your function)
# ```
#
# **HINT: Notice that we are adding a new column, not replacing an existing one!**

# %%
### GRADED

### YOUR SOLUTION HERE

df_subset['New sex'] = df_subset.Sex.map(lambda x: 'male' if x == 'M' else 'female')

df_subset




###
### YOUR CODE HERE
###
# Out:
#             ID   Age  Height  Weight Sex New sex
# 0            1  24.0   180.0    80.0   M    male
# 1            2  23.0   170.0    60.0   M    male
# 2            3  24.0     NaN     NaN   M    male
# 3            4  34.0     NaN     NaN   M    male
# 4            5  21.0   185.0    82.0   F  female
# 5            5  21.0   185.0    82.0   F  female
# 6            5  25.0   185.0    82.0   F  female
# 7            5  25.0   185.0    82.0   F  female
# 8            5  27.0   185.0    82.0   F  female
# 9            5  27.0   185.0    82.0   F  female
# 10           6  31.0   188.0    75.0   M    male
# 11           6  31.0   188.0    75.0   M    male
# 12           6  31.0   188.0    75.0   M    male
# 13           6  31.0   188.0    75.0   M    male
# 14           6  33.0   188.0    75.0   M    male
# 15           6  33.0   188.0    75.0   M    male
# 16           6  33.0   188.0    75.0   M    male
# 17           6  33.0   188.0    75.0   M    male
# 18           7  31.0   183.0    72.0   M    male
# 19           7  31.0   183.0    72.0   M    male
# 20           7  31.0   183.0    72.0   M    male
# 21           7  31.0   183.0    72.0   M    male
# 22           7  33.0   183.0    72.0   M    male
# 23           7  33.0   183.0    72.0   M    male
# 24           7  33.0   183.0    72.0   M    male
# 25           7  33.0   183.0    72.0   M    male
# 26           8  18.0   168.0     NaN   F  female
# 27           8  18.0   168.0     NaN   F  female
# 28           9  26.0   186.0    96.0   M    male
# 29          10  26.0     NaN     NaN   M    male
# ...        ...   ...     ...     ...  ..     ...
# 271086  135555  23.0   177.0    68.0   M    male
# 271087  135556  19.0   189.0    80.0   M    male
# 271088  135556  19.0   189.0    80.0   M    male
# 271089  135557  34.0   192.0    95.0   M    male
# 271090  135557  38.0   192.0    95.0   M    male
# 271091  135558  32.0   200.0    89.0   M    male
# 271092  135559  21.0   182.0    79.0   M    male
# 271093  135559  21.0   182.0    79.0   M    male
# 271094  135559  25.0   182.0    79.0   M    male
# 271095  135559  25.0   182.0    79.0   M    male
# 271096  135559  29.0   182.0    79.0   M    male
# 271097  135559  29.0   182.0    79.0   M    male
# 271098  135559  33.0   182.0    79.0   M    male
# 271099  135560  36.0   171.0    63.0   F  female
# 271100  135561  26.0     NaN     NaN   M    male
# 271101  135562  24.0   173.0    68.0   M    male
# 271102  135563  19.0   171.0    64.0   F  female
# 271103  135563  23.0   171.0    64.0   F  female
# 271104  135564  22.0   172.0    65.0   M    male
# 271105  135565  23.0   168.0    76.0   M    male
# 271106  135565  27.0   168.0    76.0   M    male
# 271107  135566  21.0   175.0    75.0   M    male
# 271108  135567  24.0   183.0    72.0   M    male
# 271109  135567  28.0   183.0    72.0   M    male
# 271110  135568  33.0   171.0    69.0   F  female
# 271111  135569  29.0   179.0    89.0   M    male
# 271112  135570  27.0   176.0    59.0   M    male
# 271113  135570  27.0   176.0    59.0   M    male
# 271114  135571  30.0   185.0    96.0   M    male
# 271115  135571  34.0   185.0    96.0   M    male
#
# [271116 rows x 6 columns]

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# ### Indexing and selecting data from Dataframes
#
# In this part of the assignment we will work with the dataframes from above to select specific data using Pandas different methods and attributes. You have learned to use `loc[]` and `iloc[]` to do this.

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 8
# *5 points*
#
# Create a new dataframe called `df_1` by selecting the following from the dataframe `df`:
# - the rows with labels from 3 through 11.
# - the columns from `ID` to `Height`.

# %%
### GRADED

### YOUR SOLUTION HERE
df_1 = df.loc[3:11, 'ID':'Height']
df_1


###
### YOUR CODE HERE
###
# Out:
#     ID                      Name Sex   Age  Height
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN
# 4    5  Christine Jacoba Aaftink   F  21.0   185.0
# 5    5  Christine Jacoba Aaftink   F  21.0   185.0
# 6    5  Christine Jacoba Aaftink   F  25.0   185.0
# 7    5  Christine Jacoba Aaftink   F  25.0   185.0
# 8    5  Christine Jacoba Aaftink   F  27.0   185.0
# 9    5  Christine Jacoba Aaftink   F  27.0   185.0
# 10   6           Per Knut Aaland   M  31.0   188.0
# 11   6           Per Knut Aaland   M  31.0   188.0

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 9
# *10 points*
#
# Select all the rows from the dataframe `df` when the `Year` is greater than 1980. Assign this dataframe to `df_year`.
#
# Next, select all the rows in `df_year` where `Team` is equal to "China", "United States", "Italy" or "Spain". Save your results in a dataframe called `df_country`.
#
# **HINT**: To select only the desired countries, create a list containing the contries and use the function `isin` like so:
#
# ```Python
# df.Team.isin([list with countries])
# ```

# %%
### GRADED

### YOUR SOLUTION HERE

#loc all records > 1980
df_year = df.loc[df.Year > 1980]

#index the Team using isin
idx = df_year.Team.isin(["China", "United States", "Italy", "Spain"])

#subset df_year w/ loc using the index for the Teams above
df_country = df_year.loc[idx]


df_country
###
### YOUR CODE HERE
###
# Out:
#             ID                               Name Sex   Age  Height  Weight  \
# 0            1                          A Dijiang   M  24.0   180.0    80.0
# 1            2                           A Lamusi   M  23.0   170.0    60.0
# 10           6                    Per Knut Aaland   M  31.0   188.0    75.0
# 270724          Italy  ITA  1984 Summer  1984  Summer     Los Angeles
# 270762          Italy  ITA  1984 Summer  1984  Summer     Los Angeles
# 270803  United States  USA  1996 Summer  1996  Summer         Atlanta
# 270807          Spain  ESP  1988 Summer  1988  Summer           Seoul
# 270808          Spain  ESP  1992 Summer  1992  Summer       Barcelona
# 270809          Spain  ESP  1996 Summer  1996  Summer         Atlanta
# 270813          Spain  ESP  1988 Summer  1988  Summer           Seoul
# 270816          Spain  ESP  1998 Winter  1998  Winter          Nagano
# 270817          Spain  ESP  2002 Winter  2002  Winter  Salt Lake City
# 270818          Spain  ESP  2002 Winter  2002  Winter  Salt Lake City
# 270819          Spain  ESP  2002 Winter  2002  Winter  Salt Lake City
# 270820          Spain  ESP  2000 Summer  2000  Summer          Sydney
# 270821          Spain  ESP  2004 Summer  2004  Summer          Athina
# 270822          China  CHN  1984 Summer  1984  Summer     Los Angeles
# 270849  United States  USA  2004 Summer  2004  Summer          Athina
# 270850  United States  USA  2004 Summer  2004  Summer          Athina
# 270851  United States  USA  2008 Summer  2008  Summer         Beijing
# 270852  United States  USA  2008 Summer  2008  Summer         Beijing
# 270891          Spain  ESP  1988 Summer  1988  Summer           Seoul
# 270892          Spain  ESP  1992 Summer  1992  Summer       Barcelona
#
#                        Sport  \
# 0                 Basketball
# 1                       Judo
# 10      Cross Country Skiing
# 11      Cross Country Skiing
# 12      Cross Country Skiing
# 13      Cross Country Skiing
# 14      Cross Country Skiing
# 15      Cross Country Skiing
# 16      Cross Country Skiing
# 17      Cross Country Skiing
# 18      Cross Country Skiing
# 19      Cross Country Skiing
# 20      Cross Country Skiing
# 21      Cross Country Skiing
# 22      Cross Country Skiing
# 23      Cross Country Skiing
# 24      Cross Country Skiing
# 25      Cross Country Skiing
# 139               Gymnastics
# 140               Gymnastics
# 141               Gymnastics
# 142               Gymnastics
# 143               Gymnastics
# 144               Gymnastics
# 148                Athletics
# 158                   Rowing
# 159                  Fencing
# 167               Basketball
# 182               Water Polo
# 186                Wrestling
# ...                      ...
# 270678               Sailing
# 270682                Rowing
# 270683                Rowing
# 270691               Sailing
# 270692               Sailing
# 270708         Speed Skating
# 270709         Speed Skating
# 270710         Speed Skating
# 270711         Speed Skating
# 270717           Ski Jumping
# 270724              Shooting
# 270762             Athletics
# 270803             Wrestling
# 270807             Athletics
# 270808             Athletics
# 270809             Athletics
# 270813              Handball
# 270816  Cross Country Skiing
# 270817  Cross Country Skiing
# 270818  Cross Country Skiing
# 270819  Cross Country Skiing
# 270820                Rowing
# 270821                Rowing
# 270822            Volleyball
# 270849              Canoeing
# 270850              Canoeing
# 270851              Canoeing
# 270852              Canoeing
# 270891         Weightlifting
# 270892         Weightlifting
#
#                                                     Event   Medal
# 0                             Basketball Men's Basketball     NaN
# 1                            Judo Men's Extra-Lightweight     NaN
# 10               Cross Country Skiing Men's 10 kilometres     NaN
# 11               Cross Country Skiing Men's 50 kilometres     NaN
# 12      Cross Country Skiing Men's 10/15 kilometres Pu...     NaN
# 13      Cross Country Skiing Men's 4 x 10 kilometres R...     NaN
# 14               Cross Country Skiing Men's 10 kilometres     NaN
# 15               Cross Country Skiing Men's 30 kilometres     NaN
# 16      Cross Country Skiing Men's 10/15 kilometres Pu...     NaN
# 17      Cross Country Skiing Men's 4 x 10 kilometres R...     NaN
# 18               Cross Country Skiing Men's 10 kilometres     NaN
# 19               Cross Country Skiing Men's 50 kilometres     NaN
# 20      Cross Country Skiing Men's 10/15 kilometres Pu...     NaN
# 21      Cross Country Skiing Men's 4 x 10 kilometres R...     NaN
# 22               Cross Country Skiing Men's 10 kilometres     NaN
# 23               Cross Country Skiing Men's 30 kilometres     NaN
# 24      Cross Country Skiing Men's 10/15 kilometres Pu...     NaN
# 25      Cross Country Skiing Men's 4 x 10 kilometres R...     NaN
# 139                Gymnastics Men's Individual All-Around     NaN
# 140                       Gymnastics Men's Floor Exercise     NaN
# 141                        Gymnastics Men's Parallel Bars     NaN
# 142                       Gymnastics Men's Horizontal Bar     NaN
# 143                                Gymnastics Men's Rings     NaN
# 144                      Gymnastics Men's Pommelled Horse     NaN
# 148                          Athletics Men's 5,000 metres     NaN
# 158                            Rowing Men's Coxless Pairs  Bronze
# 159                        Fencing Men's epee, Individual  Bronze
# 167                         Basketball Women's Basketball     NaN
# 182                           Water Polo Men's Water Polo    Gold
# 186              Wrestling Men's Featherweight, Freestyle  Silver
# ...                                                   ...     ...
# 270678                                Sailing Men's Skiff     NaN
# 270682                          Rowing Men's Coxed Eights     NaN
# 270683                          Rowing Men's Coxed Eights     NaN
# 270691                            Sailing Mixed Multihull     NaN
# 270692                            Sailing Mixed Multihull     NaN
# 270708                 Speed Skating Women's 1,500 metres     NaN
# 270709                 Speed Skating Women's 3,000 metres     NaN
# 270710                 Speed Skating Women's 1,500 metres     NaN
# 270711                 Speed Skating Women's 3,000 metres     NaN
# 270717           Ski Jumping Men's Large Hill, Individual     NaN
# 270724        Shooting Women's Sporting Pistol, 25 metres     NaN
# 270762               Athletics Men's 4 x 400 metres Relay     NaN
# 270803         Wrestling Men's Featherweight, Greco-Roman     NaN
# 270807                       Athletics Women's 800 metres     NaN
# 270808                     Athletics Women's 1,500 metres     NaN
# 270809                     Athletics Women's 1,500 metres     NaN
# 270813                            Handball Men's Handball     NaN
# 270816           Cross Country Skiing Men's 50 kilometres     NaN
# 270817           Cross Country Skiing Men's 30 kilometres     NaN
# 270818           Cross Country Skiing Men's 50 kilometres     NaN
# 270819  Cross Country Skiing Men's 10/10 kilometres Pu...     NaN
# 270820             Rowing Men's Lightweight Double Sculls     NaN
# 270821             Rowing Men's Lightweight Double Sculls     NaN
# 270822                        Volleyball Men's Volleyball     NaN
# 270849           Canoeing Men's Kayak Singles, 500 metres     NaN
# 270850           Canoeing Men's Kayak Doubles, 500 metres     NaN
# 270851           Canoeing Men's Kayak Singles, 500 metres     NaN
# 270852         Canoeing Men's Kayak Singles, 1,000 metres     NaN
# 270891                   Weightlifting Men's Bantamweight     NaN
# 270892                   Weightlifting Men's Bantamweight     NaN
#
# [22533 rows x 15 columns]

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 10
# *5 points*
#
# Using the function `iloc()` select the rows with index 0, 10, 20, 40, 43, 66 and the columns with index 0, 3, 5 from the dataframe `df`. Store your results in a dataframe called `df_3`.

# %%
### GRADED

### YOUR SOLUTION HERE
df_3 = df.iloc[[0, 10, 20, 40, 43, 66], [0, 3, 5]]
df_3
###
### YOUR CODE HERE
###
# Out:
#     ID   Age  Weight
# 0    1  24.0    80.0
# 10   6  31.0    75.0
# 20   7  31.0    72.0
# 40  16  28.0    85.0
# 43  17  28.0    64.0
# 66  20  22.0    85.0

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# ### Editing data in DataFrames and Combining DataFrames
#
# In this section we will modify the internal structure and data of dataframes, deleting some of its columns and transforming others. We will also be combining our dataframes `df` and `regions` and learn different ways of working with them.

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 11
# *10 points*
#
# Use a `left` join to combine the dataframes `df` and `regions`, in this particular order, into a new dataframe called `merged`. Set the column `NOC` as the key column.
#
# **HINT**: Use the `pandas` function `merge`.

# %%
### GRADED

# Let's read our data again to have the original datasets
df = pd.read_csv("data/athlete_events.csv")
regions = pd.read_csv("data/noc_regions.csv")

### YOUR SOLUTION HERE
merged = pd.merge(df, regions, on = "NOC", how = "left")
merged.head()

###pd.merge(df_first_names, df_last_names, on = "STUDENT_ID", how = "inner")

###
### YOUR CODE HERE
###
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# 1      Judo Men's Extra-Lightweight   NaN        China   NaN
# 2           Football Men's Football   NaN      Denmark   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN
# 4  Speed Skating Women's 500 metres   NaN  Netherlands   NaN

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# ### Grouping and Aggregating DataFrames
#
# In this final section we will group and perform aggregations on our dataframes.

# %%
# Let's read our data again to have the original datasets
df = pd.read_csv("data/athlete_events.csv")
regions = pd.read_csv("data/noc_regions.csv")
regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 12
# *10 points*
#
# Reshape the `regions` dataframe by setting:
# - index = `region`
# - columns = `NOC`
# - values = `notes`
#
# Assign the new dataframe to `regions_stacked`

# %%
### GRADED

### YOUR SOLUTION HERE

regions_stacked = regions.pivot(index = 'region', columns = 'NOC', values = 'notes')

regions_stacked
###
### YOUR CODE HERE
###
# Out:
# NOC                      AFG  AHO  ALB  ALG  AND  ANG                  ANT  \
# region
# NaN                      NaN  NaN  NaN  NaN  NaN  NaN                  NaN
# Afghanistan              NaN  NaN  NaN  NaN  NaN  NaN                  NaN
# Albania                  NaN  NaN  NaN  NaN  NaN  NaN                  NaN
# Algeria                  NaN  NaN  NaN  NaN  NaN  NaN                  NaN
# American Samoa           NaN  NaN  NaN  NaN  NaN  NaN                  NaN
# Andorra                  NaN  NaN  NaN  NaN  NaN  NaN                  NaN
# Angola                   NaN  NaN  NaN  NaN  NaN  NaN                  NaN
# Antigua                  NaN  NaN  NaN  NaN  NaN  NaN  Antigua and Barbuda
# Argentina                NaN  NaN  NaN  NaN  NaN  NaN                  NaN
#
# Botswana                         NaN  NaN  NaN  NaN
# Brazil                           NaN  NaN  NaN  NaN
# Brunei                           NaN  NaN  NaN  NaN
# Bulgaria                         NaN  NaN  NaN  NaN
# ...                              ...  ...  ...  ...
# Swaziland                        NaN  NaN  NaN  NaN
# Sweden                           NaN  NaN  NaN  NaN
# Switzerland                      NaN  NaN  NaN  NaN
# Syria                            NaN  NaN  NaN  NaN
# Taiwan                           NaN  NaN  NaN  NaN
# Tajikistan                       NaN  NaN  NaN  NaN
# Tanzania                         NaN  NaN  NaN  NaN
# Thailand                         NaN  NaN  NaN  NaN
# Timor-Leste                      NaN  NaN  NaN  NaN
# Togo                             NaN  NaN  NaN  NaN
# Tonga                            NaN  NaN  NaN  NaN
# Trinidad                         NaN  NaN  NaN  NaN
# Tunisia                          NaN  NaN  NaN  NaN
# Turkey                           NaN  NaN  NaN  NaN
# Turkmenistan                     NaN  NaN  NaN  NaN
# UK                               NaN  NaN  NaN  NaN
# USA                              NaN  NaN  NaN  NaN
# Uganda                           NaN  NaN  NaN  NaN
# Ukraine                          NaN  NaN  NaN  NaN
# United Arab Emirates             NaN  NaN  NaN  NaN
# Uruguay                          NaN  NaN  NaN  NaN
# Uzbekistan                       NaN  NaN  NaN  NaN
# Vanuatu                          NaN  NaN  NaN  NaN
# Venezuela                        NaN  NaN  NaN  NaN
# Vietnam                          NaN  NaN  NaN  NaN
# Virgin Islands, British          NaN  NaN  NaN  NaN
# Virgin Islands, US               NaN  NaN  NaN  NaN
# Yemen                    South Yemen  NaN  NaN  NaN
# Zambia                           NaN  NaN  NaN  NaN
# Zimbabwe                         NaN  NaN  NaN  NaN
#
# [207 rows x 230 columns]

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 13
# *10 points*
#
# Group the entries of the dataframe `df` by `Season` and `Medal`. Assign the new dataframe to `season_medal`. In which Olympic games did the first group of athletes participate?
#
# - a) 2014 Winter
# - b) 1920 Summer
# - c) 1994 Summer
# - d) 1920 Winter
#
# Assign character, as a string, to `ans13`.

# %%
### GRADED

### YOUR SOLUTION HERE
season_medal = df.groupby(["Season", "Medal"])

season_medal.first()
ans13 = "b"


###
### YOUR CODE HERE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# [Back to top](#Index:)
#
# ### Question 14
# *10 points*
#
# Perform the following aggregation operations on `df`:
#
# - compute the `max` and the `min` on the column `Age`.
# - Compute the `mean` on the column `Weight`.
# - compute the `max`, `min` and `mean` on the column `Height`.
#
# Assign the new dataframe to `df_aggr`.

# %%
### GRADED

### YOUR SOLUTION HERE
df_aggr = df.aggregate({ "Age":['max', 'min'], 
              "Weight":['mean'],  
              "Height":['max', 'min','mean']}) 

df_aggr

###
### YOUR CODE HERE
###
# Out:
#        Age     Weight     Height
# max   97.0        NaN  226.00000
# mean   NaN  70.702393  175.33897
# min   10.0        NaN  127.00000

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###
